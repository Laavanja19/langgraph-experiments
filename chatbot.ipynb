# %%
from typing import TypedDict, Annotated
from langgraph.graph.message import add_messages
# Out:
# C:\code\langgraph-learning\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model("google_genai:gemini-flash-latest")

# %%
response = llm.invoke("Who is the first person to land on Moon?")
print(response)
# Out:
# content=[{'type': 'text', 'text': 'The first person to land on the Moon was **Neil Armstrong**.\n\nHe stepped onto the lunar surface on **July 20, 1969**, as part of NASA\'s **Apollo 11** mission. Upon stepping onto the surface, he famously said: *"That\'s one small step for [a] man, one giant leap for mankind."*\n\nHe was followed shortly after by **Buzz Aldrin**, while their teammate **Michael Collins** remained in orbit around the Moon in the command module.', 'extras': {'signature': '...'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019d3069-bd6d-7301-9616-ed8450011a32-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 11, 'output_tokens': 281, 'total_tokens': 292, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 174}}

# %%
class State(TypedDict) :
    messages: Annotated[list,add_messages]

# %%
def chatbot(state: State) -> State :
    return {"messages":[llm.invoke(state["messages"])]}

# %%
from langgraph.graph import StateGraph,START,END

builder = StateGraph(State)

builder.add_node("chatbot_node",chatbot)
builder.add_edge(START, "chatbot_node")
builder.add_edge("chatbot_node",END)

# %%
graph = builder.compile()

# %%
from IPython.display import Image,display

display(graph)

# %%
message = {"role":"user","content" : "Who walked on the Moon first? Print only the name"}

response = graph.invoke({"messages":[message]})

response["messages"]
# Out:
# [HumanMessage(content='Who walked on the Moon first? Print only the name', additional_kwargs={}, response_metadata={}, id='2fd07692-4ed2-45b6-9e5e-c2578c1837da'),
#  AIMessage(content='Neil Armstrong', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d2fd1-688f-7f50-8536-5cfe24eab890-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 45, 'total_tokens': 57, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 43}})]

# %%
#message = {"role":"user","content" : "Who is the prime minister of Sri Lanka in 2025?"}
message = {"role":"user","content" : "Who is the current prime minister of Sri Lanka?"}

response = graph.invoke({"messages":[message]})

response["messages"]
# Out:
# [HumanMessage(content='Who is the current prime minister of Sri Lanka?', additional_kwargs={}, response_metadata={}, id='36e15032-1acb-45c7-a858-444bcf05e34e'),
#  AIMessage(content=[{'type': 'text', 'text': 'The current Prime Minister of Sri Lanka is **Harini Amarasuriya**. \n\nShe was sworn in on September 24, 2024, by President Anura Kumara Dissanayake. She is the first woman to hold the office in 24 years.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d3069-f39c-77f2-bed1-10b3eab01e8c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 290, 'total_tokens': 301, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 230}})]
